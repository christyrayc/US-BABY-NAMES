# %% [markdown]
# The US authorities have registered the names of all US citizens born since 1880. The record is publicly available. For data protection reasons, only names that have been used at least 5 times are listed in the data record.

# %% [markdown]
# Define Questions:
# choose any name , open and empy dict input year , counts and sum up frequency

# %%
import pandas as pd

# %%
df4 = pd.read_csv('/Users/christianaosatoamehraymond/Downloads/master_df.csv')

# %%
jefferson_count = {'year': [], 'counts_jeff': []}

def parse_dataset(data):
    count = data.loc[data['name'] == 'Jefferson', 'frequency'].sum()
    return count

for year in range(1880, 2021):
    data = df.loc[df['year'] == year]
    count = parse_dataset(data)
    jefferson_count['year'].append(year)
    jefferson_count['counts_jeff'].append(count)

print(jefferson_count)
# Out:
# {'year': [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], 'counts_jeff': [43, 31, 34, 32, 39, 38, 34, 32, 33, 39, 39, 40, 40, 25, 30, 28, 23, 17, 38, 11, 24, 27, 24, 20, 21, 22, 25, 32, 25, 24, 25, 4
# ...

# %%
df5 = pd.DataFrame(jefferson_count)
df5
# Out:
#      year  counts_jeff
# 0    1880           43
# 1    1881           31
# 2    1882           34
# 3    1883           32
# 4    1884           39
# ..    ...          ...
# 136  2016          432
# 137  2017          353
# 138  2018          364
# 139  2019          326
# 140  2020          356
#
# [141 rows x 2 columns]

# %% [markdown]
# Solve the one-liner challenges

# %%
import pandas as pd

# %%
# 1. Read in data:
df = pd.read_csv('yob1881 (1).csv')
df
# Out:
#            Mary  F  6919
# 0          Anna  F  2698
# 1          Emma  F  2034
# 2     Elizabeth  F  1852
# 3      Margaret  F  1658
# 4        Minnie  F  1653
# ...         ... ..   ...
# 1928     Wiliam  M     5
# 1929     Wilton  M     5
# 1930       Wing  M     5
# 1931       Wood  M     5
# 1932     Wright  M     5
#
# [1933 rows x 3 columns]

# %%
frequency_column = df['frequency']
print(frequency_column)
# Out:
# 0          34
# 1          38
# 2          38
# 3          38
# 4          37
#            ..
# 2085153    32
# 2085154    32
# 2085155    32
# 2085156    32
# 2085157     5
# Name: frequency, Length: 2085158, dtype: int64

# %%
gender_frequency_columns = df[['gender', 'frequency']]
print(gender_frequency_columns)
# Out:
#         gender  frequency
# 0            F         34
# 1            M         38
# 2            M         38
# 3            M         38
# 4            M         37
# ...        ...        ...
# 2085153      M         32
# 2085154      M         32
# 2085155      M         32
# 2085156      M         32
# 2085157      M          5
#
# [2085158 rows x 2 columns]

# %%
# 4. display the data for row(s) containing William


william_rows = df[df['gender'] == 'M']
(william_rows)
# Out:
#              name gender  frequency  year
# 1         Clifton      M         38  1880
# 2          Lucius      M         38  1880
# 3          Porter      M         38  1880
# 4          Arnold      M         37  1880
# 5             Bud      M         37  1880
# ...           ...    ...        ...   ...
# 2085153     Iziah      M         32  2022
# 2085154     Jahan      M         32  2022
# 2085155   Jahkari      M         32  2022
# 2085156  Chauncey      M         32  2022
# 2085157    Zymeer      M          5  2022
#
# [857363 rows x 4 columns]

# %%
# 5. display the data for all rows with William, Paul, and Anne
names = ['William', 'Paul', 'Anne']
selected_rows = df[df['name'].isin(names)]
(selected_rows)
# Out:
#             name gender  frequency  year
# 391      William      F         30  1880
# 1228     William      M       9532  1880
# 1474        Paul      M        301  1880
# 1604        Anne      F        136  1880
# 2489        Paul      M        291  1881
# ...          ...    ...        ...   ...
# 2043154     Anne      F        510  2021
# 2060483  William      F          7  2022
# 2063523     Anne      F        520  2022
# 2077830     Paul      M       1326  2022
# 2080618  William      M      11282  2022
#
# [773 rows x 4 columns]

# %% [markdown]
# ### Aggregate several datasets together

# %%
import pandas as pd

# %%
df2 = pd.read_csv('yob1880.csv')

# %%
df = pd.DataFrame(jefferson_count)
df
# Out:
#      year  counts_jeff
# 0    1880           43
# 1    1881           31
# 2    1882           34
# 3    1883           32
# 4    1884           39
# ..    ...          ...
# 136  2016          432
# 137  2017          353
# 138  2018          364
# 139  2019          326
# 140  2020          356
#
# [141 rows x 2 columns]

# %%
df1 =  pd.read_csv('yob1881 (1).csv')

# %%
df1
# Out:
#            Mary  F  6919
# 0          Anna  F  2698
# 1          Emma  F  2034
# 2     Elizabeth  F  1852
# 3      Margaret  F  1658
# 4        Minnie  F  1653
# ...         ... ..   ...
# 1928     Wiliam  M     5
# 1929     Wilton  M     5
# 1930       Wing  M     5
# 1931       Wood  M     5
# 1932     Wright  M     5
#
# [1933 rows x 3 columns]

# %%
combon = pd.concat([df,df1])

# %%
combon
# Out:
#         year  counts_jeff    Mary    F  6919
# 0     1880.0         43.0     NaN  NaN   NaN
# 1     1881.0         31.0     NaN  NaN   NaN
# 2     1882.0         34.0     NaN  NaN   NaN
# 3     1883.0         32.0     NaN  NaN   NaN
# 4     1884.0         39.0     NaN  NaN   NaN
# ...      ...          ...     ...  ...   ...
# 1928     NaN          NaN  Wiliam    M   5.0
# 1929     NaN          NaN  Wilton    M   5.0
# 1930     NaN          NaN    Wing    M   5.0
# 1931     NaN          NaN    Wood    M   5.0
# 1932     NaN          NaN  Wright    M   5.0
#
# [2074 rows x 5 columns]

# %% [markdown]
# Analyze Data
# Simple metrics

# %%
Hd = df4['frequency'].mean()

# %%
Hd
# Out:
# 1482.6559409648785

# %%
d2 = df4['name'].mode()

# %%
d2
# Out:
# 0     Francis
# 1       James
# 2        Jean
# 3       Jesse
# 4      Jessie
# 5        John
# 6     Johnnie
# 7      Joseph
# 8         Lee
# 9      Leslie
# 10     Marion
# 11      Ollie
# 12     Sidney
# 13     Tommie
# 14    William
# Name: name, dtype: object

# %%
c2 = df4['frequency'].std()

# %%
c2
# Out:
# 1482.6559409648785

# %% [markdown]
# Present Data to Stakeholders
# Create explanatory plots of the data
# Plot the timeline of baby name(s)
# Develop and present your own visualization

# %%
import matplotlib.pyplot as plt

# %%
# Create explanatory plots of the data
births_dict = {'year': [], 'total_births': []}

def parse_dataset(year_data):
    total_births = year_data['frequency'].sum()
    return total_births

for year in range(1880, 2021):
    year_data = df4.loc[df4['year'] == year]
    parsed_data = parse_dataset(year_data)
    births_dict['year'].append(year)
    births_dict['total_births'].append(parsed_data)

print(births_dict)
# Out:
# {'year': [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], 'total_births': [201484, 192690, 221533, 216945, 243461, 240854, 255317, 247393, 299473, 288946, 301401, 286671, 334374, 325223, 338690, 3510
# ...
